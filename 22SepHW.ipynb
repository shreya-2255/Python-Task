# %% [markdown]
# ## HomeWork
# Data type: String

# %%
name = "Smruti Santosh Gadekar"
print(len(name))
# Out:
# 22

# %%
print(name[0], name[-1])
# Out:
# S r

# %%
print(name[0], name[1], name[2], name[3], name[4], name[5])
# Out:
# S m r u t i

# %%
print(name[-12])
# Out:
# t

# %%
print(name[-7], name[-6], name[-5], name[-4], name[-3], name[-2], name[-1])
# Out:
# G a d e k a r

# %%
print(name[8], name[12])
# Out:
# a s

# %%
print(name[-21], name[-9])
# Out:
# m h

# %%
print(name[1])
# Out:
# m

# %%
print(name[11], name[12], name[13], name[14])
# Out:
# o s h
