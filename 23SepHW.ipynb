# %% [markdown]
# ## String

# %%
Name = "Smruti Gadekar"
print(Name[:6])
# Out:
# Smruti

# %%
print(Name[2:5])
# Out:
# rut

# %%
print(Name[:-1])
# Out:
# Smruti Gadeka

# %%
print(Name[::-1])
# Out:
# rakedaG iturmS

# %%
print(Name[-1:-7:-1])
# Out:
# rakeda

# %%
print(Name[1:13:2])
# Out:
# muiGdk

# %%
print(Name[5:10])
# Out:
# i Gad

# %%
print(Name[3:8])
# Out:
# uti G

# %%
print(Name[6:])
# Out:
#  Gadekar

# %%
print(Name[1:10:2])
# Out:
# muiGd

# %%
print(Name[12:0:-2])
# Out:
# aea tr

# %%
print(Name[0:7])
# Out:
# Smruti

# %%
print(Name[::2])
# Out:
# Srt aea

# %%
print(Name[::])
# Out:
# Smruti Gadekar
